# %% [markdown]
# <a href="https://colab.research.google.com/github/cheul0518/DeepLearning/blob/main/Practice/Unet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

HEIGHT = 128
WIDTH = 128
CHANNELS = 3

inputs = tf.keras.layers.Input((HEIGHT, WIDTH, CHANNELS))
# To make integer floating point values in inputs
inputs_scaled = tf.keras.layers.Lambda(lambda x:x/255)(inputs)

# Contraction path
## C1
c1 = tf.keras.layers.Conv2D(16, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs_scaled)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2,2))(c1)
## C2
c2 = tf.keras.layers.Conv2D(32, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2,2))(c2)
## C3
c3 = tf.keras.layers.Conv2D(64, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(64, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2,2))(c3)
## C4
c4 = tf.keras.layers.Conv2D(128, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(128, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D((2,2))(c4)
## C5 
c5 = tf.keras.layers.Conv2D(256, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
c5 = tf.keras.layers.Dropout(0.3)(c5)
c5 = tf.keras.layers.Conv2D(256, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

# Expansive path
## C6
u6 = tf.keras.layers.Conv2DTranspose(128, (2,2), strides=(2,2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6,c4])
c6 = tf.keras.layers.Conv2D(128, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
c6 = tf.keras.layers.Dropout(0.2)(c6)
c6 = tf.keras.layers.Conv2D(128, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
## C7
u7 = tf.keras.layers.Conv2DTranspose(64, (2,2), strides=(2,2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7,c3])
c7 = tf.keras.layers.Conv2D(64, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
c7 = tf.keras.layers.Dropout(0.2)(c7)
c7 = tf.keras.layers.Conv2D(64, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
## C8
u8 = tf.keras.layers.Conv2DTranspose(32, (2,2), strides=(2,2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8,c2])
c8 = tf.keras.layers.Conv2D(32, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
c8 = tf.keras.layers.Dropout(0.1)(c8)
c8 = tf.keras.layers.Conv2D(32, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
## C9
u9 = tf.keras.layers.Conv2DTranspose(16, (2,2), strides=(2,2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9,c1])
c9 = tf.keras.layers.Conv2D(16, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
c9 = tf.keras.layers.Dropout(0.1)(c9)
c9 = tf.keras.layers.Conv2D(16, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

outputs = tf.keras.layers.Conv2D(1, (1,1), activation='sigmoid')(c9)

model =tf.keras.Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  lambda_5 (Lambda)              (None, 128, 128, 3)  0           ['input_6[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 128, 128, 16  448         ['lambda_5[0][0]']
#                                 )
#
#  dropout_45 (Dropout)           (None, 128, 128, 16  0           ['conv2d_93[0][0]']
#                                 )
#
#  conv2d_94 (Conv2D)             (None, 128, 128, 16  2320        ['dropout_45[0][0]']
#                                 )
#
#  max_pooling2d_20 (MaxPooling2D  (None, 64, 64, 16)  0           ['conv2d_94[0][0]']
#  )
#
#  conv2d_95 (Conv2D)             (None, 64, 64, 32)   4640        ['max_pooling2d_20[0][0]']
#
#  dropout_46 (Dropout)           (None, 64, 64, 32)   0           ['conv2d_95[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 64, 64, 32)   9248        ['dropout_46[0][0]']
#
#  max_pooling2d_21 (MaxPooling2D  (None, 32, 32, 32)  0           ['conv2d_96[0][0]']
#  )
#
#  conv2d_97 (Conv2D)             (None, 32, 32, 64)   18496       ['max_pooling2d_21[0][0]']
#
#  dropout_47 (Dropout)           (None, 32, 32, 64)   0           ['conv2d_97[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 32, 32, 64)   36928       ['dropout_47[0][0]']
#
#  max_pooling2d_22 (MaxPooling2D  (None, 16, 16, 64)  0           ['conv2d_98[0][0]']
#  )
#
#  conv2d_99 (Conv2D)             (None, 16, 16, 128)  73856       ['max_pooling2d_22[0][0]']
#
#  dropout_48 (Dropout)           (None, 16, 16, 128)  0           ['conv2d_99[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 16, 16, 128)  147584      ['dropout_48[0][0]']
#
#  max_pooling2d_23 (MaxPooling2D  (None, 8, 8, 128)   0           ['conv2d_100[0][0]']
#  )
#
#  conv2d_101 (Conv2D)            (None, 8, 8, 256)    295168      ['max_pooling2d_23[0][0]']
#
#  dropout_49 (Dropout)           (None, 8, 8, 256)    0           ['conv2d_101[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 8, 8, 256)    590080      ['dropout_49[0][0]']
#
#  conv2d_transpose_20 (Conv2DTra  (None, 16, 16, 128)  131200     ['conv2d_102[0][0]']
#  nspose)
#
#  concatenate_20 (Concatenate)   (None, 16, 16, 256)  0           ['conv2d_transpose_20[0][0]',
#                                                                   'conv2d_100[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 16, 16, 128)  295040      ['concatenate_20[0][0]']
#
#  dropout_50 (Dropout)           (None, 16, 16, 128)  0           ['conv2d_103[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 16, 16, 128)  147584      ['dropout_50[0][0]']
#
#  conv2d_transpose_21 (Conv2DTra  (None, 32, 32, 64)  32832       ['conv2d_104[0][0]']
#  nspose)
#
#  concatenate_21 (Concatenate)   (None, 32, 32, 128)  0           ['conv2d_transpose_21[0][0]',
#                                                                   'conv2d_98[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 32, 32, 64)   73792       ['concatenate_21[0][0]']
#
#  dropout_51 (Dropout)           (None, 32, 32, 64)   0           ['conv2d_105[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 32, 32, 64)   36928       ['dropout_51[0][0]']
#
#  conv2d_transpose_22 (Conv2DTra  (None, 64, 64, 32)  8224        ['conv2d_106[0][0]']
#  nspose)
#
#  concatenate_22 (Concatenate)   (None, 64, 64, 64)   0           ['conv2d_transpose_22[0][0]',
#                                                                   'conv2d_96[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 64, 64, 32)   18464       ['concatenate_22[0][0]']
#
#  dropout_52 (Dropout)           (None, 64, 64, 32)   0           ['conv2d_107[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 64, 64, 32)   9248        ['dropout_52[0][0]']
#
#  conv2d_transpose_23 (Conv2DTra  (None, 128, 128, 16  2064       ['conv2d_108[0][0]']
#  nspose)                        )
#
#  concatenate_23 (Concatenate)   (None, 128, 128, 32  0           ['conv2d_transpose_23[0][0]',
#                                 )                                 'conv2d_94[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 128, 128, 16  4624        ['concatenate_23[0][0]']
#                                 )
#
#  dropout_53 (Dropout)           (None, 128, 128, 16  0           ['conv2d_109[0][0]']
#                                 )
#
#  conv2d_110 (Conv2D)            (None, 128, 128, 16  2320        ['dropout_53[0][0]']
#                                 )
#
#  conv2d_111 (Conv2D)            (None, 128, 128, 1)  17          ['conv2d_110[0][0]']
#
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________
